# %%
import pandas as pd
import numpy as np
import keras
from keras import layers
from sklearn.metrics import (confusion_matrix, precision_score, auc,
                             roc_curve, recall_score, classification_report, f1_score)
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
import random
import scipy.stats as stats
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import csv
from sklearn.cluster import KMeans
from sklearn_som.som import SOM
from sklearn import svm

# %% [markdown]
# # Dados NSL-KDD

# %%
kddtrain = pd.read_csv("kddtrain_onehot.csv").to_numpy()
kddtest = pd.read_csv("kddtest_onehot.csv").to_numpy()

# %% [markdown]
# # Abordagem Autoencoder-KNN

# %%
data = np.concatenate((kddtrain,kddtest), axis=0)
epochs = 50
batch_size = 256
optimizer = Adam(learning_rate=0.0001)
activation = "relu"
neighbors = 11

acc_per_fold = []
loss_per_fold = []
num_folds = 10

kfold = KFold(n_splits=num_folds, shuffle=True)

fold_no = 1
count = 0

#Métricas ErroRecons
matrix_ErroRecons = np.zeros((num_folds,2,2))
accuracy_ErroRecons = np.zeros(num_folds)
recall_ErroRecons = np.zeros(num_folds)
precision_ErroRecons = np.zeros(num_folds)
f1_ErroRecons = np.zeros(num_folds)

#Métricas KNN
matrix_knn = np.zeros((num_folds,2,2))
accuracy_knn = np.zeros(num_folds)
recall_knn = np.zeros(num_folds)
precision_knn = np.zeros(num_folds)
f1_knn = np.zeros(num_folds)

#Métricas KMeans
matrix_kmeans = np.zeros((num_folds,2,2))
accuracy_kmeans = np.zeros(num_folds)
recall_kmeans = np.zeros(num_folds)
precision_kmeans = np.zeros(num_folds)
f1_kmeans = np.zeros(num_folds)

#Métricas SVM
matrix_svm = np.zeros((num_folds,2,2))
accuracy_svm = np.zeros(num_folds)
recall_svm = np.zeros(num_folds)
precision_svm = np.zeros(num_folds)
f1_svm = np.zeros(num_folds)

for train, test in kfold.split(data[::, 0:data.shape[1]-3], data[::, data.shape[1]-1]):
    
    #####################################################
    ####Pré-Processamento
    
    #Separação dos Folds de Treinamento e Teste
    dataTrain = data[train]
    dataTest = data[test]
    
    #Conta Quantidade de dados
    Train = dataTrain.shape[1]
    noTrain = np.count_nonzero(dataTrain[:,Train-1] == 1)
    anTrain = np.count_nonzero(dataTrain[:, Train-1] == 0)

    #Separa dados normais e anômalos
    normalTrain = dataTrain[np.where(dataTrain[:,Train-1] == 1)]
    anomalyTrain = dataTrain[np.where(dataTrain[:,Train-1] == 0)]
    
    #Divide dados para treinamento
    porcen = 0.50
    j = int(noTrain * porcen)
    
    #Índices escolhidos aleatoriamente
    numbers_knn_normal = np.array(random.sample(range(0, normalTrain.shape[0]),j))
    numbers_knn_anomaly = np.array(random.sample(range(0,anomalyTrain.shape[0]),j))
    numbers_autoencoder_normal = np.array(list(set(np.arange(0, normalTrain.shape[0])) - set(numbers_knn_normal)))
    
    #Dados KNN
    knnTrain_normal = normalTrain[numbers_knn_normal]
    knnTrain_anomaly = anomalyTrain[numbers_knn_anomaly]
    knnTrain = np.concatenate((knnTrain_normal, knnTrain_anomaly), axis=0)
    
    #Dados Autoencoder
    autoencoderTrain = normalTrain[numbers_autoencoder_normal]
    
    #Normalização
    scaler = MinMaxScaler()
    scaler.fit(autoencoderTrain)
    autoencoderTrain = scaler.transform(autoencoderTrain)

    scaler1 = MinMaxScaler()
    scaler1.fit(knnTrain)
    knnTrain = scaler1.transform(knnTrain)

    dataTest = scaler1.transform(dataTest)
    
    ###Separação das Características e classes
    autoencoderTrain_class = autoencoderTrain[::, autoencoderTrain.shape[1]-2:autoencoderTrain.shape[1]]
    autoencoderTrain = autoencoderTrain[::, 0:autoencoderTrain.shape[1]-3]

    knnTrain_class = knnTrain[::, knnTrain.shape[1]-2:knnTrain.shape[1]]
    knnTrain = knnTrain[::, 0:knnTrain.shape[1]-3]

    modelTest_class = dataTest[::, dataTest.shape[1]-2:dataTest.shape[1]]
    modelTest = dataTest[::, 0:dataTest.shape[1]-3]
    
    #####################################################
    ####Autoencoder
    #Modela as camadas do Autoencoder
    var = autoencoderTrain.shape[1]
    input_vector = keras.Input(shape=(var,))
    en1 = layers.Dense(32, activation=activation)(input_vector)
    en2 = layers.Dense(16, activation=activation)(en1)
    de1 = layers.Dense(32, activation=activation)(en2)
    de2 = layers.Dense(var, activation=activation)(de1)

    #Gera o modelo
    autoencoder = keras.Model(input_vector, de2)
    
    encoder = keras.Model(input_vector, en2)
    encoded_input = keras.Input(shape=(16,))
    decoder_layer = autoencoder.layers[-2]
    decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

    #Compila o modelo
    autoencoder.compile(optimizer=optimizer, loss="mean_squared_error")

    #Treina o modelo
    history = autoencoder.fit(autoencoderTrain, autoencoderTrain, epochs = epochs, batch_size = batch_size, shuffle = True)
    
    
    #####################################################
    ####Erro de Reconstrução
    #Teste
    pred_ErroRecons = autoencoder.predict(modelTest)
    
    #Extração do erro
    mse_ErroRecons = np.mean(np.power(modelTest - pred_ErroRecons, 2), axis=1)
    error_df_ErroRecons = pd.DataFrame({'reconstruction_error': mse_ErroRecons,
                              'true_class': modelTest_class[:,1]})
    
    #Limiar de Separação
    media = np.mean(error_df_ErroRecons['reconstruction_error'])
    desv = np.std(error_df_ErroRecons['reconstruction_error'])
    Z = 0
    teta = media + Z*desv
    
    #Separação dos erros
    predi_ErroRecons = np.zeros(modelTest.shape[0])
    error_ErroRecons = error_df_ErroRecons.to_numpy()
    predi_ErroRecons[np.where(error_ErroRecons[:,0] <= teta)] = 1
    
    #Métricas
    accuracy_ErroRecons[count] = accuracy_score(error_ErroRecons[:,1], predi_ErroRecons[:])
    recall_ErroRecons[count] = recall_score(error_ErroRecons[:,1], predi_ErroRecons[:])
    precision_ErroRecons[count] = precision_score(error_ErroRecons[:,1], predi_ErroRecons[:])
    f1_ErroRecons[count] = f1_score(error_ErroRecons[:,1], predi_ErroRecons[:])
    matrix_ErroRecons[count] = confusion_matrix(error_ErroRecons[:,1], predi_ErroRecons[:])
    
    #####################################################
    ####KNN
    ###Treinamento KNN
    pred_knn = autoencoder.predict(knnTrain)
    mse_knn = np.mean(np.power(knnTrain - pred_knn, 2), axis=1)
    error_df_knn = pd.DataFrame({'reconstruction_error': mse_knn,
                                 'true_class': knnTrain_class[::,1]})
    error_knn = error_df_knn.to_numpy()
    encoder_layer = encoder.predict(knnTrain)
    error_encoder = encoder_layer
    neigh = KNeighborsClassifier(n_neighbors=neighbors)
    neigh.fit(error_encoder[:,0:error_encoder.shape[1] - 2], error_knn[:,1])
    
    #Teste do Modelo
    pred_knn = autoencoder.predict(modelTest)
    mse_knn = np.mean(np.power(modelTest - pred_knn, 2), axis=1)
    error_df_knn = pd.DataFrame({'reconstruction_error': mse_knn,
                                'true_class': modelTest_class[::,1]})
    error_knn = error_df_knn.to_numpy()
    encoder_layer = encoder.predict(modelTest)
    error_encoder = encoder_layer
    predict_knn = neigh.predict(error_encoder[:,0:error_encoder.shape[1] - 2])
    
    #Métricas
    accuracy_knn[count] = accuracy_score(error_knn[:,1], predict_knn[:])
    recall_knn[count] = recall_score(error_knn[:,1], predict_knn[:])
    precision_knn[count] = precision_score(error_knn[:,1], predict_knn[:])
    f1_knn[count] = f1_score(error_knn[:,1], predict_knn[:])
    matrix_knn[count] = confusion_matrix(error_knn[:,1], predict_knn[:])
    
    #####################################################
    ####KMeans
    ###Treinamento KMeans 
    pred_kmeans = autoencoder.predict(knnTrain)
    mse_kmeans = np.mean(np.power(knnTrain - pred_kmeans, 2), axis=1)
    error_df_kmeans = pd.DataFrame({'reconstruction_error': mse_kmeans,
                                     'true_class': knnTrain_class[::,1]})
    error_kmeans = error_df_kmeans.to_numpy()
    encoder_layer = encoder.predict(knnTrain)
    error_encoder = encoder_layer
    kmeans = KMeans(n_clusters=2, random_state=0).fit(error_encoder[:,0:error_encoder.shape[1]-2])
    kmeans.labels_

    #Teste
    pred_kmeans = autoencoder.predict(modelTest)
    mse_kmeans = np.mean(np.power(modelTest - pred_kmeans, 2), axis=1)
    error_df_kmeans = pd.DataFrame({'reconstruction_error': mse_kmeans,
                                     'true_class': modelTest_class[::,1]})
    error_kmeans = error_df_kmeans.to_numpy()
    encoder_layer = encoder.predict(modelTest)
    error_encoder = encoder_layer
    predict_kmeans = kmeans.predict(error_encoder[:,0:error_encoder.shape[1]-2])

    #Métricas
    accuracy_kmeans[count] = accuracy_score(error_kmeans[:,1], predict_kmeans[:])
    recall_kmeans[count] = recall_score(error_kmeans[:,1], predict_kmeans[:])
    precision_kmeans[count] = precision_score(error_kmeans[:,1], predict_kmeans[:])
    f1_kmeans[count] = f1_score(error_kmeans[:,1], predict_kmeans[:])
    matrix_kmeans[count] = confusion_matrix(error_kmeans[:,1], predict_kmeans[:])
    
    #####################################################
    ####SVM
    #Treinamento SVM
    pred_svm = autoencoder.predict(knnTrain)
    mse_svm = np.mean(np.power(knnTrain - pred_svm, 2), axis=1)
    error_df_svm = pd.DataFrame({'reconstruction_error': mse_svm,
                                     'true_class': knnTrain_class[::,1]})
    error_svm = error_df_svm.to_numpy()
    encoder_layer = encoder.predict(knnTrain)
    error_encoder = encoder_layer
    clf = svm.SVC(kernel='rbf')
    clf.fit(error_encoder[:,0:error_encoder.shape[1] - 2], error_svm[:,1])
    
    #Teste
    pred_svm = autoencoder.predict(modelTest)
    mse_svm = np.mean(np.power(modelTest - pred_svm, 2), axis=1)
    error_df_svm = pd.DataFrame({'reconstruction_error': mse_svm,
                                     'true_class': modelTest_class[::,1]})
    error_svm = error_df_svm.to_numpy()
    encoder_layer = encoder.predict(modelTest)
    error_encoder = encoder_layer
    predict_svm = clf.predict(error_encoder[:,0:error_encoder.shape[1]-2])
    
    #Métricas
    accuracy_svm[count] = accuracy_score(error_svm[:,1], predict_svm[:])
    recall_svm[count] = recall_score(error_svm[:,1], predict_svm[:])
    precision_svm[count] = precision_score(error_svm[:,1], predict_svm[:])
    f1_svm[count] = f1_score(error_svm[:,1], predict_svm[:])
    matrix_svm[count] = confusion_matrix(error_svm[:,1], predict_svm[:])

    count = count + 1
    fold_no = fold_no + 1
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E493F40D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E493F40D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 1s 2ms/step - loss: 0.0950A: 0s - loss: 0.09
# Epoch 2/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0554
# Epoch 3/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0346
# Epoch 4/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0307
# Epoch 5/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 6/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0260
# Epoch 7/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0243
# Epoch 8/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0229
# Epoch 9/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 10/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0211
# Epoch 11/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 12/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0201
# Epoch 13/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0198
# Epoch 14/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0195
# Epoch 15/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0193
# Epoch 16/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 17/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0190
# Epoch 18/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 19/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0188
# Epoch 20/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 21/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 22/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 23/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0185
# Epoch 24/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0185
# Epoch 25/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0184
# Epoch 26/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0183
# Epoch 27/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 28/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 29/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 30/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 31/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 32/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 33/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 34/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 35/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 36/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 37/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 38/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 39/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 40/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 41/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 42/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 43/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 44/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 45/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 46/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 47/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 48/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 49/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 50/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0175
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4996A438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4996A438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4AE86438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4AE86438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E49A91948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E49A91948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 1s 2ms/step - loss: 0.0545
# Epoch 2/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0293
# Epoch 3/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 4/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0210
# Epoch 5/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 6/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 7/50
# 136/136 [==============================] - ETA: 0s - loss: 0.018 - 0s 1ms/step - loss: 0.0185
# Epoch 8/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 9/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 10/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0179
# Epoch 11/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0178
# Epoch 12/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 13/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0176
# Epoch 14/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 15/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0175
# Epoch 16/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0175
# Epoch 17/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0174
# Epoch 18/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0174
# Epoch 19/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0173
# Epoch 20/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0173
# Epoch 21/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0173
# Epoch 22/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0172
# Epoch 23/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0172
# Epoch 24/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 25/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0171
# Epoch 26/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 27/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0171
# Epoch 28/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 29/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0170
# Epoch 30/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0170
# Epoch 31/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0170
# Epoch 32/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0170
# Epoch 33/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0169
# Epoch 34/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0169
# Epoch 35/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 36/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0168
# Epoch 37/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0168
# Epoch 38/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0168
# Epoch 39/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0168
# Epoch 40/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0168
# Epoch 41/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 42/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0167
# Epoch 43/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 44/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0167
# Epoch 45/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 46/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 47/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 48/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0167
# Epoch 49/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 50/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0167
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E6054D948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E6054D948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E6054DA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E6054DA68> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E49C9E948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E49C9E948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 1s 1ms/step - loss: 0.0520
# Epoch 2/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 3/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0212
# Epoch 4/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0192
# Epoch 5/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0175
# Epoch 6/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0165
# Epoch 7/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0158
# Epoch 8/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0153
# Epoch 9/50
# 136/136 [==============================] - ETA: 0s - loss: 0.014 - 0s 1ms/step - loss: 0.0149
# Epoch 10/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0147
# Epoch 11/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 12/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 13/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 14/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 15/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0139
# Epoch 16/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 17/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0137
# Epoch 18/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0137
# Epoch 19/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0136
# Epoch 20/50
# 136/136 [==============================] - ETA: 0s - loss: 0.013 - 0s 1ms/step - loss: 0.0135
# Epoch 21/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0135
# Epoch 22/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0135
# Epoch 23/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 24/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 25/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 26/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0133
# Epoch 27/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0133
# Epoch 28/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0133
# Epoch 29/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0132
# Epoch 30/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0132
# Epoch 31/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0132
# Epoch 32/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0132
# Epoch 33/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0131
# Epoch 34/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0131
# Epoch 35/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0131
# Epoch 36/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 37/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 38/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 39/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 40/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0130A: 0s - loss: 0.01
# Epoch 41/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 42/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 43/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 44/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 45/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 46/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 47/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 48/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 49/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0129
# Epoch 50/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0129
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E49D2A318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E49D2A318> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E3D9558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E3D9558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E4EC95288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E4EC95288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 1s 1ms/step - loss: 0.0648
# Epoch 2/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0321
# Epoch 3/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0284
# Epoch 4/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 5/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0183
# Epoch 6/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0102
# Epoch 7/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 8/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 9/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 10/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 11/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 12/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 13/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 14/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 15/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 16/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 17/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 18/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 19/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 20/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 21/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 22/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 23/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 24/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 25/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 26/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 27/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 28/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 29/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 30/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 31/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 32/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 33/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 34/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 35/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 36/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 37/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 38/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 39/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 40/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 41/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 42/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 43/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 44/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 45/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 46/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 47/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 48/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 49/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 50/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0071
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4CF94438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4CF94438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4D2FE5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4D2FE5E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E01277D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E01277D38> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 1s 1ms/step - loss: 0.0792
# Epoch 2/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0414
# Epoch 3/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0335
# Epoch 4/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0321
# Epoch 5/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0313
# Epoch 6/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0307
# Epoch 7/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0303A: 0s - loss: 0.0
# Epoch 8/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0299
# Epoch 9/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0296
# Epoch 10/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0293
# Epoch 11/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 12/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0288
# Epoch 13/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0287
# Epoch 14/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0286
# Epoch 15/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0285
# Epoch 16/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0284
# Epoch 17/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 18/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0282
# Epoch 19/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0281
# Epoch 20/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0281
# Epoch 21/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0281
# Epoch 22/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0280
# Epoch 23/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0280
# Epoch 24/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0280
# Epoch 25/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0279
# Epoch 26/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0279
# Epoch 27/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0279
# Epoch 28/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0279
# Epoch 29/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0279
# Epoch 30/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0279
# Epoch 31/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 32/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 33/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 34/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 35/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 36/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 37/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 38/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 39/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 40/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 41/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277
# Epoch 42/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277
# Epoch 43/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277
# Epoch 44/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 45/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277
# Epoch 46/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277
# Epoch 47/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277A: 0s - loss: 0.027
# Epoch 48/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277
# Epoch 49/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277
# Epoch 50/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0277
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E000710D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E000710D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E5FCAB558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E5FCAB558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E49AF4E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E49AF4E58> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 1s 2ms/step - loss: 0.0473
# Epoch 2/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 3/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 4/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 5/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0087
# Epoch 6/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 7/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 8/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 9/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 10/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 11/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 12/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 13/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 14/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 15/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 16/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 17/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 18/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 19/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 20/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 21/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 22/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 23/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 24/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 25/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 26/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 27/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 28/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 29/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 30/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 31/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 32/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 33/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 34/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 35/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 36/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 37/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 38/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 39/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 40/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 41/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 42/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 43/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 44/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 45/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 46/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 47/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 48/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 49/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 50/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0058
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4980F288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4980F288> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E595B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E595B88> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E4E3C3438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E4E3C3438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 1s 1ms/step - loss: 0.0654
# Epoch 2/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0274
# Epoch 3/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 4/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0214
# Epoch 5/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0206
# Epoch 6/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0201
# Epoch 7/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0198
# Epoch 8/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0196
# Epoch 9/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0194
# Epoch 10/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0192
# Epoch 11/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0191A: 0s - loss: 0.
# Epoch 12/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 13/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0188
# Epoch 14/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0187
# Epoch 15/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0187
# Epoch 16/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0186
# Epoch 17/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0185
# Epoch 18/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0185
# Epoch 19/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0184
# Epoch 20/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0184
# Epoch 21/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0184
# Epoch 22/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0183
# Epoch 23/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0183
# Epoch 24/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0183
# Epoch 25/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 26/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0182
# Epoch 27/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 28/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 29/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 30/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 31/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 32/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 33/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0181
# Epoch 34/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0181
# Epoch 35/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0181
# Epoch 36/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0181
# Epoch 37/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0181
# Epoch 38/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0181
# Epoch 39/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 40/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 41/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 42/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 43/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 44/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 45/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 46/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 47/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 48/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 49/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# Epoch 50/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0180
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E5FDE0948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E5FDE0948> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E5FE21AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E5FE21AF8> and will run it as-is.
# ...
# Epoch 47/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 48/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 49/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 50/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0268
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E00DA85E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E00DA85E8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E00E0F708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E00E0F708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E49E3A9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E49E3A9D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 4s 2ms/step - loss: 0.0664
# Epoch 2/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0471
# Epoch 3/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0436
# Epoch 4/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0419
# Epoch 5/50
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0411
# Epoch 6/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0407
# Epoch 7/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0404
# Epoch 8/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0402
# Epoch 9/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0401
# Epoch 10/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0399
# Epoch 11/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0398
# Epoch 12/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0397
# Epoch 13/50
# 136/136 [==============================] - 0s 3ms/step - loss: 0.0396
# Epoch 14/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0396
# Epoch 15/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0395
# Epoch 16/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0394
# Epoch 17/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0394
# Epoch 18/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0392
# Epoch 19/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0391
# Epoch 20/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0390
# Epoch 21/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0390
# Epoch 22/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0389
# Epoch 23/50
# 136/136 [==============================] - ETA: 0s - loss: 0.038 - 0s 2ms/step - loss: 0.0389
# Epoch 24/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0388
# Epoch 25/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0388
# Epoch 26/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 27/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 28/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 29/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 30/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 31/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 32/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 33/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 34/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 35/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 36/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 37/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 38/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 39/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 40/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 41/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 42/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 43/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 44/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0385
# Epoch 45/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 46/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 47/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 48/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 49/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 50/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0385
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E3D9798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E3D9798> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E3D90D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E3D90D8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E462EC708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000020E462EC708> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 136/136 [==============================] - 4s 2ms/step - loss: 0.0470
# Epoch 2/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 3/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 4/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0084
# Epoch 5/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 6/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0066
# Epoch 7/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 8/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0058
# Epoch 9/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0056
# Epoch 10/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 11/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 12/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 13/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0049
# Epoch 14/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 15/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0047
# Epoch 16/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 17/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0045
# Epoch 18/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 19/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 20/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 21/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 22/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0042
# Epoch 23/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 24/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0042
# Epoch 25/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 26/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 27/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 28/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 29/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 30/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 31/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 32/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 33/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 34/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 35/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 36/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 37/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 38/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 39/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 40/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 41/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 42/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 43/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 44/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 45/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 46/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 47/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 48/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 49/50
# 136/136 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 50/50
# 136/136 [==============================] - 0s 1ms/step - loss: 0.0038
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E595CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E4E595CA8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E00B83828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x0000020E00B83828> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
print("Autoencoder - Erro de Reconstrução:\n", np.mean(matrix_ErroRecons, axis=0), "\nAcurácia: ", np.mean(accuracy_ErroRecons),' +/- ',np.std(accuracy_ErroRecons), "\nRecall: ", np.mean(recall_ErroRecons),' +/- ',np.std(recall_ErroRecons), "\nPrecision: ", np.mean(precision_ErroRecons),' +/- ',np.std(precision_ErroRecons), "\nF1: ", np.mean(f1_ErroRecons),' +/- ',np.std(f1_ErroRecons))

print("\nAutoencoder - KNN:\n", np.mean(matrix_knn, axis=0), "\nAcurácia: ", np.mean(accuracy_knn), ' +/- ', np.std(accuracy_knn), "\nRecall: ", np.mean(recall_knn), ' +/- ', np.std(recall_knn), "\nPrecision: ", np.mean(precision_knn), ' +/- ', np.std(precision_knn), "\nF1: ", np.mean(f1_knn), ' +/- ', np.std(f1_knn))

print("\nAutoencoder - SVM:\n", np.mean(matrix_svm, axis=0), "\nAcurácia: ", np.mean(accuracy_svm), ' +/- ', np.std(accuracy_svm), "\nRecall: ", np.mean(recall_svm), ' +/- ', np.std(recall_svm), "\nPrecision: ", np.mean(precision_svm), ' +/- ', np.std(precision_svm), "\nF1: ", np.mean(f1_svm), ' +/- ', np.std(f1_svm))

print("\nAutoencoder - KMeans:\n", np.mean(matrix_kmeans, axis=0), "\nAcurácia: ", np.mean(accuracy_kmeans), ' +/- ', np.std(accuracy_kmeans), "\nRecall: ", np.mean(recall_kmeans), ' +/- ', np.std(recall_kmeans), "\nPrecision: ", np.mean(precision_kmeans), ' +/- ', np.std(precision_kmeans), "\nF1: ", np.mean(f1_kmeans), ' +/- ', np.std(f1_kmeans))
# Out:
# Autoencoder - Erro de Reconstrução:
#  [[5183.1 1963.1]
#  [ 875.  6830.3]]
# Acurácia:  0.8089027172562473  +/-  0.14694092528948247
# Recall:  0.886844719035784  +/-  0.18724190328605922
# Precision:  0.7671497641154917  +/-  0.12808407960674795
# F1:  0.8215712832104402  +/-  0.15562379210834248
#
# Autoencoder - KNN:
#  [[6999.   147.2]
#  [ 143.4 7561.9]]
# Acurácia:  0.9804329238620826  +/-  0.0018322990900083436
# Recall:  0.9813866029767547  +/-  0.00191076945323704
# Precision:  0.9809188091148002  +/-  0.0024125061052743145
# F1:  0.9811508304428846  +/-  0.0017183204738659566
#
# Autoencoder - SVM:
#  [[6704.5  441.7]
#  [ 187.7 7517.6]]
# Acurácia:  0.9576203738716152  +/-  0.0037014634804285198
# Recall:  0.9756363566696129  +/-  0.0043421417876421484
# Precision:  0.9446142008063809  +/-  0.008121808764215142
# F1:  0.9598401481743537  +/-  0.0032413598588545258
#
# Autoencoder - KMeans:
#  [[2762.7 4383.5]
#  [7446.3  259. ]]
# Acurácia:  0.20346177542419164  +/-  0.07381878095206205
# Recall:  0.033619653611137126  +/-  0.02492860590282241
# Precision:  0.054751321546968545  +/-  0.03964513379610844
# F1:  0.04016858575525169  +/-  0.02760744397890353

# %%
#Salva Resultados
with open('Resultados_InterLayer.csv', 'a', newline='') as csvfile:
    fieldnames = ['Algoritmo','Métrica', 'Média', 'Desvio']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    writer.writerow({'Algoritmo': 'ErroRecons_acurácia','Métrica': accuracy_ErroRecons, 'Média': np.mean(accuracy_ErroRecons), 'Desvio': np.std(accuracy_ErroRecons)})
    writer.writerow({'Algoritmo': 'ErroRecons_recall','Métrica': recall_ErroRecons, 'Média': np.mean(recall_ErroRecons), 'Desvio': np.std(recall_ErroRecons)})
    writer.writerow({'Algoritmo': 'ErroRecons_precision','Métrica': precision_ErroRecons, 'Média': np.mean(precision_ErroRecons), 'Desvio': np.std(precision_ErroRecons)})
    writer.writerow({'Algoritmo': 'ErroRecons_f1','Métrica': f1_ErroRecons, 'Média': np.mean(f1_ErroRecons), 'Desvio': np.std(f1_ErroRecons)})
    writer.writerow({'Algoritmo': 'ErroRecons_matrix','Métrica': matrix_ErroRecons, 'Média': np.mean(matrix_ErroRecons, axis=0), 'Desvio': np.std(matrix_ErroRecons, axis=0)})
    
    writer.writerow({'Algoritmo': 'KNN_acurácia','Métrica': accuracy_knn, 'Média': np.mean(accuracy_knn), 'Desvio': np.std(accuracy_knn)})
    writer.writerow({'Algoritmo': 'KNN_recall','Métrica': recall_knn, 'Média': np.mean(recall_knn), 'Desvio': np.std(recall_knn)})
    writer.writerow({'Algoritmo': 'KNN_precision','Métrica': precision_knn, 'Média': np.mean(precision_knn), 'Desvio': np.std(precision_knn)})
    writer.writerow({'Algoritmo': 'KNN_f1','Métrica': f1_knn, 'Média': np.mean(f1_knn), 'Desvio': np.std(f1_knn)})
    writer.writerow({'Algoritmo': 'KNN_matrix','Métrica': matrix_knn, 'Média': np.mean(matrix_knn, axis=0), 'Desvio': np.std(matrix_knn, axis=0)})
    
    writer.writerow({'Algoritmo': 'SVM_acurácia','Métrica': accuracy_svm, 'Média': np.mean(accuracy_svm), 'Desvio': np.std(accuracy_svm)})
    writer.writerow({'Algoritmo': 'SVM_recall','Métrica': recall_svm, 'Média': np.mean(recall_svm), 'Desvio': np.std(recall_svm)})
    writer.writerow({'Algoritmo': 'SVM_precision','Métrica': precision_svm, 'Média': np.mean(precision_svm), 'Desvio': np.std(precision_svm)})
    writer.writerow({'Algoritmo': 'SVM_f1','Métrica': f1_svm, 'Média': np.mean(f1_svm), 'Desvio': np.std(f1_svm)})
    writer.writerow({'Algoritmo': 'SVM_matrix','Métrica': matrix_svm, 'Média': np.mean(matrix_svm, axis=0), 'Desvio': np.std(matrix_svm, axis=0)})
    
    writer.writerow({'Algoritmo': 'KMeans_acurácia','Métrica': accuracy_kmeans, 'Média': np.mean(accuracy_kmeans), 'Desvio': np.std(accuracy_kmeans)})
    writer.writerow({'Algoritmo': 'KMeans_recall','Métrica': recall_kmeans, 'Média': np.mean(recall_kmeans), 'Desvio': np.std(recall_kmeans)})
    writer.writerow({'Algoritmo': 'KMeans_precision','Métrica': precision_kmeans, 'Média': np.mean(precision_kmeans), 'Desvio': np.std(precision_kmeans)})
    writer.writerow({'Algoritmo': 'KMeans_f1','Métrica': f1_kmeans, 'Média': np.mean(f1_kmeans), 'Desvio': np.std(f1_kmeans)})
    writer.writerow({'Algoritmo': 'KMeans_matrix','Métrica': matrix_kmeans, 'Média': np.mean(matrix_kmeans, axis=0), 'Desvio': np.std(matrix_kmeans, axis=0)})
